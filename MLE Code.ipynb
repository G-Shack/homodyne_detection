# %%
import sympy as sm
import numpy as np
import matplotlib.pyplot as plt
from homodyne import *
from scipy.optimize import curve_fit
from scipy.linalg import sqrtm
from scipy.special import comb
import sqtdiat.qops as sq
from qutip import fidelity, Qobj
from tqdm import tqdm
import seaborn as sns

plt.style.use("ggplot")

def d_s(li):
    if type(li) != np.array:
        li = np.array(li, dtype = 'complex128')
    if sum(np.abs(li)**2) != 1:
        li /= np.sqrt(np.sum(np.abs(li)**2))
    return np.outer(li, li.conjugate().T)

def gaussian(x, amplitude, mean, stddev, offset):
    return amplitude * np.exp(-((x - mean) / stddev)**2 / 2) + offset

# %%
def den_2_prob(rho, xv = np.linspace(-10, 10, 1000), theta = 0):
    prob_ = np.zeros_like(xv, dtype = 'complex128')
    if type(rho) != np.array: rho = np.array(rho)
    for n in range(rho.shape[0]):
        for m in range(n + 1):
            if np.abs(rho[n, m]) > 1e-7: 
                elem = rho[n, m]
                # + np.arctan(np.real(elem) / np.imag(elem))
                prob_ += elem * quad(n, m, xv, theta)
                if m != n:
                    prob_ += elem.conjugate() * quad(n, m, xv, theta)
    return np.abs(prob_)
q, theta = sm.symbols('q theta')
n = sm.symbols('n', integer = True)
m = sm.symbols('m', integer = True)

n_xtheta = sm.exp(-q**2 / 2) * sm.hermite(n, q) / sm.sqrt(2**n * sm.factorial(n)) * (1 / sm.pi) ** (1 / 4) * sm.exp(1j * (n * theta - sm.pi / 2))
nxt = sm.lambdify((n, q, theta), n_xtheta)

def quad(n, m, q, theta):
    return nxt(n, q, theta) * nxt(m, q, theta).conjugate()

def get_data(rho, pts = 10, angles = 360, xv = np.linspace(-10, 10, 1000)):
    data = np.zeros((pts * angles))
    thetas = np.linspace(0, 2 * np.pi, angles)
    for angle, th in zip(thetas, range(angles)):
        prob = den_2_prob(rho, xv, theta = angle)
        data[th * pts: (th + 1) * pts] = np.random.choice(a = xv, p = prob / np.sum(prob), size = (pts))
    return data

def B(n, k, eta):
    return np.sqrt(comb(n + k, n) * eta ** n * (1 - eta) ** k)

def R_(data, theta_data, den = np.eye(10)):
    R_mat = np.zeros_like(den)
    N, M = np.mgrid[:den.shape[0], :den.shape[0]]
    for th, q in zip(theta_data, data):
        op = quad(N, M, q, th - np.pi / 2)
        R_mat += op / np.trace(op @ den)
    return R_mat

def perform_MLE(data, theta_data, dims, iters = 20):
    # global fid
    fid = []
    global MK
    rho = np.eye(dims, dtype = 'complex128')
    R = R_(data, theta_data, rho)
    for item in tqdm(range(iters), desc = "MLE in progress"):
        rho = R @ rho @ R
        rho /= np.trace(rho)
        R = R_(data, theta_data, rho)
    return rho.T

# %%
test_rho = np.zeros((10, 10))
test_rho[1, 1] = 1
theta_data = np.linspace(0, 2 * np.pi, 1000)
data = get_data(test_rho, pts = 1, angles = 1000)

plt.scatter(theta_data, data)

# %%
rho = perform_MLE(data, theta_data, dims = 3, iters = 1000)
# Out:
# MLE in progress: 100%|██████████| 1000/1000 [00:30<00:00, 33.20it/s]

# %%
plt.bar(range(3), np.diag(np.real(rho)))
plt.xlabel("n")
plt.ylabel('P(n)')
# Out:
# Text(0, 0.5, 'P(n)')

# %%
plt.imshow(np.real(rho))

# %%
# Experimental data courtesy of Lvovsky and Team

# For generated data from generate_flock.py, do not divide by 50.
data_one = np.loadtxt("ONEPHOTONFOCK_qnoise.txt")[::10]

# Match ideal reference to detector efficiency used in generate_flock.py
eta = 0.55
ideal_rho_one = np.zeros((10, 10), dtype = 'complex128')
ideal_rho_one[0, 0] = 1 - eta
ideal_rho_one[1, 1] = eta
theta_data_one = np.linspace(0, 2 * np.pi, len(data_one))
ideal_data_one = get_data(ideal_rho_one, pts = 1, angles = len(data_one))

plt.figure(figsize = (10, 5))
plt.suptitle("Experimental vs Ideal One Photon Fock State Data")
plt.subplot(1, 2, 1)
plt.scatter(theta_data_one, data_one, s = 5, color = "blue", alpha = 0.4, label = "Experimental")
plt.scatter(theta_data_one, ideal_data_one, s = 5, color = "orange", alpha = 0.35, label = "Ideal (eta = 0.55)")
plt.xlabel("LO Phase")
plt.ylabel("O/P Voltage (Normalized)")
plt.legend()

plt.subplot(1, 2, 2)
plt.hist(ideal_data_one, bins = 100, alpha = 0.6, label = "Ideal (eta = 0.55)")
plt.hist(data_one, bins = 100, alpha = 0.6, label = "Experimental")
plt.xlabel("O/P Voltage Normalized")
plt.ylabel("Counts per bin")
plt.legend()
plt.show()

# %%
dims_one = 10
rho_one = perform_MLE(data_one, theta_data_one, iters = 1000, dims = dims_one)
# Out:
# MLE in progress: 100%|██████████| 1000/1000 [05:48<00:00,  2.87it/s]

# %%
plt.figure(figsize = (10, 5))
plt.subplot(1, 2, 1)
plt.bar(range(dims_one), np.diag(np.real(rho_one)))
plt.xlabel("n")
plt.ylabel("P(n)")
plt.subplot(1, 2, 2)
plt.imshow(wigner_laguerre(rho_one, x_max = 5, x_min = -5, p_max = 5, p_min = -5), cmap = 'hot')
plt.axis('off')
plt.show()

# %%
fidelity(Qobj(rho_one), Qobj(ideal_rho_one))
# Out:
# np.float64(0.9989321499041917)

# %%
def calc_errors(rho, error_iters = 20):
    empt_rho = np.zeros((error_iters, rho.shape[0], rho.shape[1]))
    theta_data = np.linspace(0, 2 * np.pi, 500, dtype = 'complex128')
    for i in range(error_iters):
        empt_rho[i] = (perform_MLE(get_data(rho, pts = 1, angles = 500), theta_data, dims = rho.shape[0]) - rho)
    return empt_rho

all_rhos = calc_errors(rho_one)
# Out:
# MLE in progress: 100%|██████████| 20/20 [00:00<00:00, 56.58it/s]
# /var/folders/j4/7rn45qh17m59wx89gt33f7mc0000gn/T/ipykernel_7206/3708929879.py:5: ComplexWarning: Casting complex values to real discards the imaginary part
#   empt_rho[i] = (perform_MLE(get_data(rho, pts = 1, angles = 500), theta_data, dims = rho.shape[0]) - rho)
# MLE in progress: 100%|██████████| 20/20 [00:00<00:00, 56.98it/s]
# MLE in progress: 100%|██████████| 20/20 [00:00<00:00, 57.08it/s]
# MLE in progress: 100%|██████████| 20/20 [00:00<00:00, 55.96it/s]
# MLE in progress: 100%|██████████| 20/20 [00:00<00:00, 55.78it/s]
# MLE in progress: 100%|██████████| 20/20 [00:00<00:00, 54.61it/s]
# MLE in progress: 100%|██████████| 20/20 [00:00<00:00, 55.19it/s]
# MLE in progress: 100%|██████████| 20/20 [00:00<00:00, 55.02it/s]
# MLE in progress: 100%|██████████| 20/20 [00:00<00:00, 55.47it/s]
# MLE in progress: 100%|██████████| 20/20 [00:00<00:00, 55.90it/s]
# MLE in progress: 100%|██████████| 20/20 [00:00<00:00, 55.30it/s]
# MLE in progress: 100%|██████████| 20/20 [00:00<00:00, 55.44it/s]
# MLE in progress: 100%|██████████| 20/20 [00:00<00:00, 56.39it/s]
# MLE in progress: 100%|██████████| 20/20 [00:00<00:00, 54.84it/s]
# MLE in progress: 100%|██████████| 20/20 [00:00<00:00, 56.88it/s]
# MLE in progress: 100%|██████████| 20/20 [00:00<00:00, 55.30it/s]
# MLE in progress: 100%|██████████| 20/20 [00:00<00:00, 54.57it/s]
# MLE in progress: 100%|██████████| 20/20 [00:00<00:00, 55.59it/s]
# MLE in progress: 100%|██████████| 20/20 [00:00<00:00, 54.77it/s]
# MLE in progress: 100%|██████████| 20/20 [00:00<00:00, 52.92it/s]

# %%
plt.bar(range(10), np.diag(np.real(rho_one)), yerr = np.diag(np.std(all_rhos, axis = 0)), capsize = 5)
# Out:
# <BarContainer object of 10 artists>
